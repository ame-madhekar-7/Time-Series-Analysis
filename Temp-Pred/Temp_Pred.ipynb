# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('GlobalLandTemperaturesByMajorCity.csv')
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
df = df.drop(['AverageTemperatureUncertainty', 'Country', 'Latitude', 'Longitude'], axis=1)
df
# Out:
#                 dt  AverageTemperature     City
# 0       1849-01-01              26.704  Abidjan
# 1       1849-02-01              27.434  Abidjan
# 2       1849-03-01              28.101  Abidjan
# 3       1849-04-01              26.140  Abidjan
# 4       1849-05-01              25.427  Abidjan
# ...            ...                 ...      ...
# 239172  2013-05-01              18.979     Xian
# 239173  2013-06-01              23.522     Xian
# 239174  2013-07-01              25.251     Xian
# 239175  2013-08-01              24.528     Xian
# 239176  2013-09-01                 NaN     Xian
#
# [239177 rows x 3 columns]

# %%
df.dtypes
# Out:
# dt                     object
# AverageTemperature    float64
# City                   object
# dtype: object

# %%
df1 = df.loc[df['City'] == 'Pune']
df1
# Out:
#                 dt  AverageTemperature  City
# 178565  1796-01-01              20.507  Pune
# 178566  1796-02-01              22.483  Pune
# 178567  1796-03-01              25.074  Pune
# 178568  1796-04-01              28.756  Pune
# 178569  1796-05-01              29.944  Pune
# ...            ...                 ...   ...
# 181173  2013-05-01              31.024  Pune
# 181174  2013-06-01              26.362  Pune
# 181175  2013-07-01              24.150  Pune
# 181176  2013-08-01              24.444  Pune
# 181177  2013-09-01                 NaN  Pune
#
# [2613 rows x 3 columns]

# %%
df1 = df1.drop('City', axis=1)
df1
# Out:
#                 dt  AverageTemperature
# 178565  1796-01-01              20.507
# 178566  1796-02-01              22.483
# 178567  1796-03-01              25.074
# 178568  1796-04-01              28.756
# 178569  1796-05-01              29.944
# ...            ...                 ...
# 181173  2013-05-01              31.024
# 181174  2013-06-01              26.362
# 181175  2013-07-01              24.150
# 181176  2013-08-01              24.444
# 181177  2013-09-01                 NaN
#
# [2613 rows x 2 columns]

# %%
df1['dt'] = pd.to_datetime(df1.dt, format = '%Y-%m-%d')
df1.dtypes
# Out:
# dt                    datetime64[ns]
# AverageTemperature           float64
# dtype: object

# %%
df1['month'] = df1.dt.dt.month
df1
# Out:
#                dt  AverageTemperature  month
# 178565 1796-01-01              20.507      1
# 178566 1796-02-01              22.483      2
# 178567 1796-03-01              25.074      3
# 178568 1796-04-01              28.756      4
# 178569 1796-05-01              29.944      5
# ...           ...                 ...    ...
# 181173 2013-05-01              31.024      5
# 181174 2013-06-01              26.362      6
# 181175 2013-07-01              24.150      7
# 181176 2013-08-01              24.444      8
# 181177 2013-09-01                 NaN      9
#
# [2613 rows x 3 columns]

# %%
df1.index = df1['dt']

# %%
df1 = df1.drop('dt', 1)

# %%
data = df1
data
# Out:
#             AverageTemperature  month
# dt
# 1796-01-01              20.507      1
# 1796-02-01              22.483      2
# 1796-03-01              25.074      3
# 1796-04-01              28.756      4
# 1796-05-01              29.944      5
# ...                        ...    ...
# 2013-05-01              31.024      5
# 2013-06-01              26.362      6
# 2013-07-01              24.150      7
# 2013-08-01              24.444      8
# 2013-09-01                 NaN      9
#
# [2613 rows x 2 columns]

# %%
plt.figure(figsize = (16,8))
Y = data['AverageTemperature']
plt.plot(Y)
plt.xlabel('Time(Year)')
plt.ylabel('Avg_Temp')
plt.legend(loc = 'best')
# Out:
# No handles with labels found to put in legend.

# %%
data
# Out:
#             AverageTemperature  month
# dt
# 1796-01-01              20.507      1
# 1796-02-01              22.483      2
# 1796-03-01              25.074      3
# 1796-04-01              28.756      4
# 1796-05-01              29.944      5
# ...                        ...    ...
# 2013-05-01              31.024      5
# 2013-06-01              26.362      6
# 2013-07-01              24.150      7
# 2013-08-01              24.444      8
# 2013-09-01                 NaN      9
#
# [2613 rows x 2 columns]

# %%
data = data.loc['2000-01-01':]
data
# Out:
#             AverageTemperature  month
# dt
# 2000-01-01              21.620      1
# 2000-02-01              22.414      2
# 2000-03-01              25.775      3
# 2000-04-01              30.013      4
# 2000-05-01              29.434      5
# ...                        ...    ...
# 2013-05-01              31.024      5
# 2013-06-01              26.362      6
# 2013-07-01              24.150      7
# 2013-08-01              24.444      8
# 2013-09-01                 NaN      9
#
# [165 rows x 2 columns]

# %%
plt.figure(figsize = (16,8))
Y = data['AverageTemperature']
plt.plot(Y)
plt.xlabel('Time(Year-Month)')
plt.ylabel('Avg_Temp')
plt.legend(loc = 'best')
# Out:
# No handles with labels found to put in legend.

# %%
train = data.loc[:'2010-12-01']
valid = data.loc['2011-01-01':'2011-12-01']

# %%
valid
# Out:
#             AverageTemperature  month
# dt
# 2011-01-01              20.286      1
# 2011-02-01              23.113      2
# 2011-03-01              27.035      3
# 2011-04-01              28.986      4
# 2011-05-01              30.319      5
# 2011-06-01              27.096      6
# 2011-07-01              24.965      7
# 2011-08-01              24.688      8
# 2011-09-01              25.092      9
# 2011-10-01              25.400     10
# 2011-11-01              23.595     11
# 2011-12-01              21.362     12

# %%
train.AverageTemperature.plot(figsize = (14, 6))
valid.AverageTemperature.plot(figsize = (14, 6))
plt.xlabel('Datetime')
plt.ylabel('Avg Temp')
plt.legend(loc = 'best')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def stationarity_check(timeseries):
    rolmean = timeseries.rolling(24).mean() # 24 hours on each day
    rolstd = timeseries.rolling(24).std()
    orig = plt.plot(timeseries, color = 'blue', label = 'Original')
    mean = plt.plot(rolmean, color = 'red', label = 'Rolling Mean')
    std = plt.plot(rolstd, color = 'black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
from matplotlib.pylab import rcParams 
rcParams['figure.figsize'] = 20,10
stationarity_check(train['AverageTemperature'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.856677
# p-value                          0.352708
# #Lags Used                      13.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64

# %%
Y = train['AverageTemperature']
Y
# Out:
# dt
# 2000-01-01    21.620
# 2000-02-01    22.414
# 2000-03-01    25.775
# 2000-04-01    30.013
# 2000-05-01    29.434
#                ...
# 2010-08-01    24.941
# 2010-09-01    25.182
# 2010-10-01    25.435
# 2010-11-01    24.295
# 2010-12-01    20.091
# Name: AverageTemperature, Length: 132, dtype: float64

# %%
train_diff = Y - Y.shift(1)

# %%
stationarity_check(train_diff.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.198244
# p-value                          0.000009
# #Lags Used                      12.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64

# %%
from statsmodels.tsa.stattools import acf, pacf 
lag_acf = acf(train_diff.dropna(), nlags=40)                          # check upto 50 past datapoints
lag_pacf = pacf(train_diff.dropna(), nlags=40, method='ols')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(lag_acf) 
plt.axhline(y=0,linestyle='--',color='gray') 
plt.axhline(y=-1.96/np.sqrt(len(train_diff.dropna())),linestyle='--',color='gray') 
plt.axhline(y=1.96/np.sqrt(len(train_diff.dropna())),linestyle='--',color='gray') 
plt.title('Autocorrelation Function') 
plt.show() 
plt.plot(lag_pacf) 
plt.axhline(y=0,linestyle='--',color='gray') 
plt.axhline(y=-1.96/np.sqrt(len(train_diff.dropna())),linestyle='--',color='gray') 
plt.axhline(y=1.96/np.sqrt(len(train_diff.dropna())),linestyle='--',color='gray') 
plt.title('Partial Autocorrelation Function') 
plt.show()

# %%
train_seas_diff = train_diff - train_diff.shift(12)
stationarity_check(train_seas_diff.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.388498
# p-value                          0.000311
# #Lags Used                      13.000000
# Number of Observations Used    105.000000
# Critical Value (1%)             -3.494220
# Critical Value (5%)             -2.889485
# Critical Value (10%)            -2.581676
# dtype: float64

# %%
from statsmodels.tsa.stattools import acf, pacf 
lag_acf = acf(train_seas_diff.dropna(), nlags=50)                          # check upto 50 past datapoints
lag_pacf = pacf(train_seas_diff.dropna(), nlags=50, method='ols')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(lag_acf) 
plt.axhline(y=0,linestyle='--',color='gray') 
plt.axhline(y=-1.96/np.sqrt(len(train_seas_diff.dropna())),linestyle='--',color='gray') 
plt.axhline(y=1.96/np.sqrt(len(train_seas_diff.dropna())),linestyle='--',color='gray') 
plt.title('Autocorrelation Function') 
plt.show() 
plt.plot(lag_pacf) 
plt.axhline(y=0,linestyle='--',color='gray') 
plt.axhline(y=-1.96/np.sqrt(len(train_seas_diff.dropna())),linestyle='--',color='gray') 
plt.axhline(y=1.96/np.sqrt(len(train_seas_diff.dropna())),linestyle='--',color='gray') 
plt.title('Partial Autocorrelation Function') 
plt.show()

# %%
import statsmodels.api as sm
y_hat_avg = valid.copy() 
fit1 = sm.tsa.statespace.SARIMAX(train.AverageTemperature, order=(4, 1, 2),seasonal_order=(3,1,1,12)).fit() 
y_hat_avg['SARIMA'] = fit1.predict(start="2011-01-01", end="2011-12-01", dynamic=True) 
plt.figure(figsize=(16,8)) 
plt.plot(Y, label='Train') 
plt.plot(valid['AverageTemperature'], label='Valid') 
plt.plot(y_hat_avg['SARIMA'], label='SARIMA') 
plt.legend(loc='best') 
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
